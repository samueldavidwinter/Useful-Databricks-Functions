# %%
kv1 = "ss-kv1" 
hostname = dbutils.secrets.get(scope = kv1, key = 'sql-server-url-hostname')
databaseName = dbutils.secrets.get(scope = kv1, key = 'sql-finance-microservice-database-name')
uName = dbutils.secrets.get(scope = kv1, key = 'sql-database-etl-user')


kv2  = "ss-kv2" 
pwd = dbutils.secrets.get(scope = kv2, key = 'sql-database-etl-user-password')

# %%
jdbcHostname = hostname
jdbcDatabase = databaseName
jdbcPort = 1433
username = uName
password = pwd

# %%
jdbcUrlFinance = "jdbc:sqlserver://{0}:{1};database={2}".format(jdbcHostname, jdbcPort, jdbcDatabase)
connectionPropertiesFinance = {
  "user" : username,
  "password" : password,
  "driver" : "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}
